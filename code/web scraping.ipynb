# %%
import pandas as pd

# %%
country=pd.read_html("https://en.wikipedia.org/wiki/List_of_territorial_entities_where_English_is_an_official_language")

# %%
t1=country[0]
t1
# Out:
#    Nr         Country Alpha-3 code                 Region  Population  \
# 0   1       Australia          AUS                Oceania    25019600
# 1   2  New Zealand[1]          NZL                Oceania     4893830
# 2   3  United Kingdom          GBR                 Europe    66040229
# 3   4   United States          USA  North America/Oceania   328239523
#
#   Primary language?
# 0               Yes
# 1               Yes
# 2               Yes
# 3               Yes

# %%
t2=country[1]
t2
# Out:
#     Nr                               Country Alpha-3 code  \
# 0    1                Antigua and Barbuda[2]          ATG
# 1    2                            Bahamas[2]          BHS
# 2    3                           Barbados[3]          BRB
# 3    4                             Belize[4]          BLZ
# 4    5                           Botswana[4]          BWA
# 5    6                            Burundi[5]          BDI
# 6    7                           Cameroon[2]          CMR
# 7    8                             Canada[2]          CAN
# 8    9                     Cook Islands[2]14          COK
# 9   10                           Dominica[2]          DMA
# 10  11                           Eswatini[2]          SWZ
# 11  12                               Fiji[2]          FJI
# 12  13                             Gambia[2]          GMB
# 13  14                              Ghana[2]          GHA
# 14  15                            Grenada[2]          GRD
# ...

# %%
t1=t1.loc[:,['Alpha-3 code','Primary language?']]
t1
# Out:
#   Alpha-3 code Primary language?
# 0          AUS               Yes
# 1          NZL               Yes
# 2          GBR               Yes
# 3          USA               Yes

# %%
t2=t2.loc[:,['Alpha-3 code','Primary language?']]
t2
# Out:
#    Alpha-3 code                                  Primary language?
# 0           ATG                                                Yes
# 1           BHS                                                Yes
# 2           BRB                                                Yes
# 3           BLZ                                                Yes
# 4           BWA                                                 No
# 5           BDI                                                 No
# 6           CMR                                                 No
# 7           CAN  Yes (except Quebec, northern New Brunswick and...
# 8           COK                                                Yes
# 9           DMA                                                Yes
# 10          SWZ                                                 No
# 11          FJI  Yes (used as lingua franca, mostly and widely ...
# 12          GMB                                                 No
# ...

# %%
#changing the column in t1
.rename(columns={'Alpha-3 code':'Country Code','Primary language?':'Primary language'},inplace=True)
t1
# Out:
#   Country Code Primary language
# 0          AUS              Yes
# 1          NZL              Yes
# 2          GBR              Yes
# 3          USA              Yes

# %%
#changing the column names in t2
t2.rename(columns={'Alpha-3 code':'Country Code','Primary language?':'Primary language'},inplace=True)
t2
# Out:
#    Country Code                                   Primary language
# 0           ATG                                                Yes
# 1           BHS                                                Yes
# 2           BRB                                                Yes
# 3           BLZ                                                Yes
# 4           BWA                                                 No
# 5           BDI                                                 No
# 6           CMR                                                 No
# 7           CAN  Yes (except Quebec, northern New Brunswick and...
# 8           COK                                                Yes
# 9           DMA                                                Yes
# 10          SWZ                                                 No
# 11          FJI  Yes (used as lingua franca, mostly and widely ...
# 12          GMB                                                 No
# ...

# %%
t2['Primary language']=t2['Primary language'].apply(lambda x:x.split(" ")[0])
t2.head(10)
# Out:
#   Country Code Primary language
# 0          ATG              Yes
# 1          BHS              Yes
# 2          BRB              Yes
# 3          BLZ              Yes
# 4          BWA               No
# 5          BDI               No
# 6          CMR               No
# 7          CAN              Yes
# 8          COK              Yes
# 9          DMA              Yes

# %%
#concat the both files
master=pd.concat([t1,t2])
master
# Out:
#    Country Code Primary language
# 0           AUS              Yes
# 1           NZL              Yes
# 2           GBR              Yes
# 3           USA              Yes
# 0           ATG              Yes
# 1           BHS              Yes
# 2           BRB              Yes
# 3           BLZ              Yes
# 4           BWA               No
# 5           BDI               No
# 6           CMR               No
# 7           CAN              Yes
# 8           COK              Yes
# 9           DMA              Yes
# 10          SWZ               No
# 11          FJI              Yes
# 12          GMB               No
# 13          GHA              Yes
# 14          GRD              Yes
# 15          GUY              Yes
# 16          IND               No
# 17          IRL              Yes
# 18          JAM              Yes
# 19          KEN              Yes
# 20          KIR               No
# 21          LSO               No
# 22          LBR              Yes
# ...

# %%
master.reset_index(drop='index',inplace=True)
master
# Out:
#    Country Code Primary language
# 0           AUS              Yes
# 1           NZL              Yes
# 2           GBR              Yes
# 3           USA              Yes
# 4           ATG              Yes
# 5           BHS              Yes
# 6           BRB              Yes
# 7           BLZ              Yes
# 8           BWA               No
# 9           BDI               No
# 10          CMR               No
# 11          CAN              Yes
# 12          COK              Yes
# 13          DMA              Yes
# 14          SWZ               No
# 15          FJI              Yes
# 16          GMB               No
# 17          GHA              Yes
# 18          GRD              Yes
# 19          GUY              Yes
# 20          IND               No
# 21          IRL              Yes
# 22          JAM              Yes
# 23          KEN              Yes
# 24          KIR               No
# 25          LSO               No
# 26          LBR              Yes
# ...

# %%
master.to_csv("f:\\countries.csv",index=False)
